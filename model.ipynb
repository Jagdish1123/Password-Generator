# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

def prepare_lstm_data(data, min_length=2):
    """Prepares sequences and mapping for LSTM"""
    if not data:
        raise ValueError("Input data is empty. Please provide password samples.")
    
    # Filter out items that are too short
    filtered_data = [item for item in data if len(item) >= min_length]
    if not filtered_data:
        raise ValueError(f"No items meet the minimum length requirement of {min_length} characters.")
    
    # Create character mappings
    chars = sorted(set("".join(filtered_data)))
    if not chars:
        raise ValueError("No valid characters found in the input data.")
    
    char_to_index = {c: i+1 for i, c in enumerate(chars)}  # 0 reserved for padding
    index_to_char = {i: c for c, i in char_to_index.items()}
    
    # Generate sequences
    sequences = []
    for item in filtered_data:
        encoded = [char_to_index[c] for c in item]
        for i in range(1, len(encoded)):
            sequences.append(encoded[:i+1])
    
    if not sequences:
        raise ValueError("No training sequences generated. Check input data format.")
    
    # Prepare X and y
    max_seq_length = max(len(seq) for seq in sequences)
    X = pad_sequences([seq[:-1] for seq in sequences], 
                     maxlen=max_seq_length-1, 
                     padding="pre",
                     value=0)
    y = [seq[-1] for seq in sequences]
    y = to_categorical(y, num_classes=len(char_to_index)+1)  # +1 for padding
    
    return X, y, max_seq_length-1, char_to_index, index_to_char

def train_lstm_model(X, y, vocab_size, max_seq_length, epochs=100):
    """Trains an LSTM model with correct output shape"""
    model = Sequential([
        Embedding(input_dim=vocab_size+1,  # +1 for padding
                 output_dim=16, 
                 input_length=max_seq_length,
                 mask_zero=True),
        LSTM(128, return_sequences=True, dropout=0.2),
        LSTM(128, dropout=0.2),
        Dense(64, activation='relu'),
        Dense(vocab_size+1, activation='softmax')  # Must match num_classes
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    
    model.fit(
        X, y,
        epochs=epochs,
        batch_size=32,
        verbose=1
    )
    
    return model

# Enhanced password components
passwords = {
    'Capital': ['ABCDE', 'BCDEF', 'CDEFG', 'DEFGH', 'EFGHI', 'FGHIJ', 'GHIJK'],
    'Word': ['alpha', 'bravo', 'charlie', 'delta', 'echo', 'foxtrot', 'golf'],
    'Numeric': ['12345', '23456', '34567', '45678', '56789', '67890', '78901'],
    'Special': ['@!@!@', '#$#$#', '%^%^%', '&*&*&', '()()(', '!@#$%', '^&*()']
}

# Train models
try:
    print("Training models...")
    X_cap, y_cap, max_cap, c2i_cap, i2c_cap = prepare_lstm_data(passwords['Capital'])
    model_cap = train_lstm_model(X_cap, y_cap, len(c2i_cap), max_cap, epochs=50)
    
    X_w, y_w, max_w, c2i_w, i2c_w = prepare_lstm_data(passwords['Word'])
    model_w = train_lstm_model(X_w, y_w, len(c2i_w), max_w, epochs=50)
    
    X_num, y_num, max_num, c2i_num, i2c_num = prepare_lstm_data(passwords['Numeric'])
    model_num = train_lstm_model(X_num, y_num, len(c2i_num), max_num, epochs=50)
    
    X_special, y_special, max_special, c2i_special, i2c_special = prepare_lstm_data(passwords['Special'])
    model_special = train_lstm_model(X_special, y_special, len(c2i_special), max_special, epochs=50)
    
    print("\nAll models trained successfully!")
    
except Exception as e:
    print(f"Error during training: {str(e)}")
# Out:
# Training models...
# Epoch 1/50
# 2025-04-20 11:55:02.125643: E tensorflow/core/util/util.cc:131] oneDNN supports DT_BOOL only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - accuracy: 0.0357 - loss: 2.4848
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.1429 - loss: 2.4826
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.1429 - loss: 2.4800
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.1429 - loss: 2.4773
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.1429 - loss: 2.4741
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.1429 - loss: 2.4707
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.1429 - loss: 2.4672
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.1429 - loss: 2.4633
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.1429 - loss: 2.4584
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.1429 - loss: 2.3101
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.1429 - loss: 2.2937
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.1429 - loss: 2.2822
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.1429 - loss: 2.2666
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.1429 - loss: 2.2493
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.1429 - loss: 2.2227
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.1429 - loss: 2.2080
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.1429 - loss: 2.1778
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.1429 - loss: 2.1659
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.1429 - loss: 2.1359
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.1429 - loss: 2.1109
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.1429 - loss: 2.0828
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.2143 - loss: 2.0508
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.2500 - loss: 2.0191
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.2143 - loss: 1.9876
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.3571 - loss: 1.9611
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.4643 - loss: 1.9027
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.4643 - loss: 1.8685
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5357 - loss: 1.8111
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5000 - loss: 1.7687
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.3571 - loss: 1.7411
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.3929 - loss: 1.6937
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.4286 - loss: 1.6497
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.5000 - loss: 1.5888
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.4643 - loss: 1.5587
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.4643 - loss: 1.4831
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.4286 - loss: 1.4704
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.4643 - loss: 1.4032
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5357 - loss: 1.3816
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6429 - loss: 1.3173
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.6429 - loss: 1.2500
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5714 - loss: 1.2525
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 0.0714 - loss: 2.3980
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.1786 - loss: 2.3969
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.1786 - loss: 2.3958
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.2500 - loss: 2.3947
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2143 - loss: 2.3935
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.2857 - loss: 2.3918
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.2500 - loss: 2.3902
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.2143 - loss: 2.3886
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.2857 - loss: 2.3868
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.2500 - loss: 2.3847
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.2500 - loss: 2.3831
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.2857 - loss: 2.3805
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.3214 - loss: 2.3762
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.2857 - loss: 2.3732
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.2500 - loss: 2.3711
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.2857 - loss: 2.3658
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.2857 - loss: 2.3608
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.2500 - loss: 2.3565
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.2143 - loss: 2.3528
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.2857 - loss: 2.3438
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.2857 - loss: 2.3402
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.2500 - loss: 2.3298
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.2500 - loss: 2.3184
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.2500 - loss: 2.3120
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.2857 - loss: 2.2973
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.2500 - loss: 2.2862
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.2500 - loss: 2.2673
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.2143 - loss: 2.2528
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.1786 - loss: 2.2362
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.2143 - loss: 2.2125
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.2143 - loss: 2.1866
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.2500 - loss: 2.1692
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.2500 - loss: 2.1344
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.2500 - loss: 2.1140
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.2500 - loss: 2.0898
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.2500 - loss: 2.0590
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.2857 - loss: 2.0314
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.2500 - loss: 2.0169
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.3929 - loss: 2.0031
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.3929 - loss: 1.9817
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.3571 - loss: 1.9423
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.3929 - loss: 1.9364
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.3929 - loss: 1.8905
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.3929 - loss: 1.8625
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.4286 - loss: 1.8508
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.4286 - loss: 1.8177
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.4643 - loss: 1.7642
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4643 - loss: 1.7714
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.4643 - loss: 1.7057
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.4643 - loss: 1.7014
#
# All models trained successfully!

# %%
import pickle
import os

# Create model directory if not exists
os.makedirs("model_artifacts", exist_ok=True)

# Save Capital model and vocab
model_cap.save("model_artifacts/cap_model.h5")
with open("model_artifacts/cap_vocab.pkl", "wb") as f:
    pickle.dump((c2i_cap, i2c_cap, max_cap), f)

# Save Word model and vocab
model_w.save("model_artifacts/word_model.h5")
with open("model_artifacts/word_vocab.pkl", "wb") as f:
    pickle.dump((c2i_w, i2c_w, max_w), f)

# Save Numeric model and vocab
model_num.save("model_artifacts/num_model.h5")
with open("model_artifacts/num_vocab.pkl", "wb") as f:
    pickle.dump((c2i_num, i2c_num, max_num), f)

# Save Special model and vocab
model_special.save("model_artifacts/special_model.h5")
with open("model_artifacts/special_vocab.pkl", "wb") as f:
    pickle.dump((c2i_special, i2c_special, max_special), f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
